# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pandas import Series,DataFrame
# %matplotlib inline

# %%
data=pd.read_csv('data.csv')
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data['Joined']
# Out:
# 0         Jul 1, 2004
# 1        Jul 10, 2018
# 2         Aug 3, 2017
# 3         Jul 1, 2011
# 4        Aug 30, 2015
#              ...
# 18202     May 3, 2017
# 18203    Mar 19, 2018
# 18204     Jul 1, 2017
# 18205    Apr 24, 2018
# 18206    Oct 30, 2018
# Name: Joined, Length: 18207, dtype: object

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
data.drop(columns=['Unnamed: 0','ID','Photo','Flag','Club','Club Logo','Special','Weak Foot','Real Face','Jersey Number','Joined'],axis=1,inplace=True)
data.head()
# Out:
#                 Name  Age Nationality  Overall  Potential    Value   Wage  \
# 0           L. Messi   31   Argentina       94         94  €110.5M  €565K
# 1  Cristiano Ronaldo   33    Portugal       94         94     €77M  €405K
# 2          Neymar Jr   26      Brazil       92         93  €118.5M  €290K
# 3             De Gea   27       Spain       91         93     €72M  €260K
# 4       K. De Bruyne   27     Belgium       91         92    €102M  €355K
#
#   Preferred Foot  International Reputation  Skill Moves  ... Composure  \
# 0           Left                       5.0          4.0  ...      96.0
# 1          Right                       5.0          5.0  ...      95.0
# 2          Right                       5.0          5.0  ...      94.0
# 3          Right                       4.0          1.0  ...      68.0
# 4          Right                       4.0          4.0  ...      88.0
#
#   Marking StandingTackle SlidingTackle GKDiving GKHandling GKKicking  \
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Value', 'Wage',
#        'Preferred Foot', 'International Reputation', 'Skill Moves',
#        'Work Rate', 'Body Type', 'Position', 'Loaned From',
#        'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW',
#        'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM',
#        'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
# ...

# %%
data.isnull().sum()
# Out:
# Name                 0
# Age                  0
# Nationality          0
# Overall              0
# Potential            0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 78, dtype: int64

# %%
data.dtypes
# Out:
# Name               object
# Age                 int64
# Nationality        object
# Overall             int64
# Potential           int64
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 78, dtype: object

# %%
columns=data.select_dtypes(exclude='object')
columns
# Out:
#        Age  Overall  Potential  International Reputation  Skill Moves  \
# 0       31       94         94                       5.0          4.0
# 1       33       94         94                       5.0          5.0
# 2       26       92         93                       5.0          5.0
# 3       27       91         93                       4.0          1.0
# 4       27       91         92                       4.0          4.0
# ...    ...      ...        ...                       ...          ...
# 18202   19       47         65                       1.0          2.0
# 18203   19       47         63                       1.0          2.0
# 18204   16       47         67                       1.0          2.0
# 18205   17       47         66                       1.0          2.0
# 18206   16       46         66                       1.0          2.0
#
#        Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  ...  \
# ...

# %%
for i in columns:
    data[i].fillna(data[i].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Name                 0
# Age                  0
# Nationality          0
# Overall              0
# Potential            0
#                   ...
# GKHandling           0
# GKKicking            0
# GKPositioning        0
# GKReflexes           0
# Release Clause    1564
# Length: 78, dtype: int64

# %%
data.dtypes['Release Clause']
# Out:
# dtype('O')

# %%
data.head()
# Out:
#                 Name  Age Nationality  Overall  Potential    Value   Wage  \
# 0           L. Messi   31   Argentina       94         94  €110.5M  €565K
# 1  Cristiano Ronaldo   33    Portugal       94         94     €77M  €405K
# 2          Neymar Jr   26      Brazil       92         93  €118.5M  €290K
# 3             De Gea   27       Spain       91         93     €72M  €260K
# 4       K. De Bruyne   27     Belgium       91         92    €102M  €355K
#
#   Preferred Foot  International Reputation  Skill Moves  ... Composure  \
# 0           Left                       5.0          4.0  ...      96.0
# 1          Right                       5.0          5.0  ...      95.0
# 2          Right                       5.0          5.0  ...      94.0
# 3          Right                       4.0          1.0  ...      68.0
# 4          Right                       4.0          4.0  ...      88.0
#
#   Marking StandingTackle SlidingTackle GKDiving GKHandling GKKicking  \
# ...

# %%
data.dtypes['Value']
# Out:
# dtype('O')

# %%
data.iloc[np.where(data['Overall']==max(data['Overall']))]['Name']
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# Name: Name, dtype: object

# %%
data['Position']
# Out:
# 0         RF
# 1         ST
# 2         LW
# 3         GK
# 4        RCM
#         ...
# 18202     CM
# 18203     ST
# 18204     ST
# 18205     RW
# 18206     CM
# Name: Position, Length: 18207, dtype: object

# %%
df=DataFrame(data.iloc[np.where(data['Overall']>90)]['Name'])
df
# Out:
#                 Name
# 0           L. Messi
# 1  Cristiano Ronaldo
# 2          Neymar Jr
# 3             De Gea
# 4       K. De Bruyne
# 5          E. Hazard
# 6          L. Modrić
# 7          L. Suárez
# 8       Sergio Ramos

# %%
forwards=DataFrame(data.iloc[np.where(data['Position']=='ST')])

# %%
top_strikers=pd.merge(df,forwards,how='inner',left_on='Name',right_on='Name')[['Name','Value']]
top_strikers
# Out:
#                 Name  Value
# 0  Cristiano Ronaldo   €77M
# 1          L. Suárez  €575K

# %%
data.iloc[np.where(data['Name']=='L. Messi')]['Position']
# Out:
# 0    RF
# Name: Position, dtype: object

# %%
for index,row in data.iterrows():
        print(row['Name']+':'+str(row['Age']))
# Out:
# L. Messi:31
# Cristiano Ronaldo:33
# Neymar Jr:26
# De Gea:27
# K. De Bruyne:27
# E. Hazard:27
# L. Modrić:32
# L. Suárez:31
# Sergio Ramos:32
# J. Oblak:25
# R. Lewandowski:29
# T. Kroos:28
# D. Godín:32
# David Silva:32
# N. Kanté:27
# P. Dybala:24
# H. Kane:24
# A. Griezmann:27
# M. ter Stegen:26
# T. Courtois:26
# Sergio Busquets:29
# E. Cavani:31
# M. Neuer:32
# S. Agüero:30
# G. Chiellini:33
# K. Mbappé:19
# M. Salah:26
# Casemiro:26
# J. Rodríguez:26
# L. Insigne:27
# Isco:26
# C. Eriksen:26
# Coutinho:26
# P. Aubameyang:29
# M. Hummels:29
# Marcelo:30
# G. Bale:28
# H. Lloris:31
# G. Higuaín:30
# Thiago Silva:33
# S. Handanovič:33
# G. Buffon:40
# S. Umtiti:24
# M. Icardi:25
# K. Koulibaly:27
# P. Pogba:25
# K. Navas:31
# R. Lukaku:25
# C. Immobile:28
# Jordi Alba:29
# D. Mertens:31
# J. Vertonghen:31
# M. Hamšík:30
# I. Rakitić:30
# Piqué:31
# L. Sané:22
# Bernardo Silva:23
# Ederson:24
# S. Mané:26
# V. van Dijk:26
# R. Sterling:23
# Roberto Firmino:26
# R. Varane:25
# ...

# %%
plt.rcParams['figure.figsize']=(25,16)
relation=sns.heatmap(data[['Age', 'Overall', 'Potential', 'Value', 'Wage',
                'Acceleration', 'Aggression', 'Agility', 'Balance', 'BallControl', 
                'Body Type','Composure', 'Crossing','Dribbling', 'FKAccuracy', 'Finishing', 
                'HeadingAccuracy', 'Interceptions','International Reputation',
                 'Jumping', 'LongPassing', 'LongShots',
                'Marking', 'Penalties', 'Position', 'Positioning',
                'ShortPassing', 'ShotPower', 'Skill Moves', 'SlidingTackle',
                'SprintSpeed', 'Stamina', 'StandingTackle', 'Strength', 'Vision',
                'Volleys']].corr(), annot = True, linewidths=.5, cmap='Blues')
relation.set_title(label='Heatmap of dataset', fontsize=20)
relation

# %%
def make_scatter(data):
    feats = ('Agility', 'Balance', 'Dribbling', 'SprintSpeed')
    
    for index, feat in enumerate(feats):
        plt.subplot(len(feats)/4+1, 4, index+1)
        ax = sns.regplot(x = 'Acceleration', y = feat, data = data)

plt.figure(figsize = (20, 20))
plt.subplots_adjust(hspace = 0.4)

make_scatter(data)

# %%
plt.figure(figsize=(12,8))
hist=sns.distplot(data['Age'],bins=58,kde=False)
hist.set_xlabel('Age',fontsize=16)
hist.set_ylabel('Number of players',fontsize=16)
hist.set_title('Distribution of age')
plt.show()

# %%
eldest=data.sort_values('Age',ascending=False)[['Name','Age']].head(5)
eldest.set_index('Name',inplace=True)
print(eldest)
# Out:
#                Age
# Name
# O. Pérez        45
# K. Pilkington   44
# T. Warner       44
# S. Narazaki     42
# C. Muñoz        41

# %%
youngest=data.sort_values('Age',ascending=True)[['Name','Age']].head(5)
youngest.set_index('Name',inplace=True)
print(youngest)
# Out:
#              Age
# Name
# G. Nugent     16
# J. Olstad     16
# H. Massengo   16
# J. Italiano   16
# N. Ayéva      16

# %%
data.groupby(['Nationality'])['Age'].mean().sort_values(ascending=False).head(5)
# Out:
# Nationality
# Oman                 36.00
# Puerto Rico          34.00
# Ethiopia             32.00
# Trinidad & Tobago    31.75
# Palestine            31.00
# Name: Age, dtype: float64

# %%
data.groupby(['Nationality'])['Age'].sum().sort_values(ascending=False).head()
# Out:
# Nationality
# England      39938
# Germany      29157
# Spain        27149
# Argentina    24555
# Brazil       22846
# Name: Age, dtype: int64

# %%
data.iloc[data.groupby(data['Position'])['Overall'].idxmax()][['Name','Position']]
# Out:
#                   Name Position
# 17        A. Griezmann      CAM
# 12            D. Godín       CB
# 20     Sergio Busquets      CDM
# 271       Luis Alberto       CF
# 67              Thiago       CM
# 3               De Gea       GK
# 28        J. Rodríguez      LAM
# 35             Marcelo       LB
# 24        G. Chiellini      LCB
# 11            T. Kroos      LCM
# 14            N. Kanté      LDM
# 5            E. Hazard       LF
# 33       P. Aubameyang       LM
# 21           E. Cavani       LS
# 2            Neymar Jr       LW
# 474          N. Schulz      LWB
# 129        J. Cuadrado      RAM
# 69         Azpilicueta       RB
# 8         Sergio Ramos      RCB
# 4         K. De Bruyne      RCM
# 45            P. Pogba      RDM
# 0             L. Messi       RF
# 25           K. Mbappé       RM
# 7            L. Suárez       RS
# 56      Bernardo Silva       RW
# 450          M. Ginter      RWB
# 1    Cristiano Ronaldo       ST

# %%
def val_to_int(data_value):
    try:
        value=float(data_value[1:-1])
        suffix=data_value[-1:]
        if suffix=='M':
            value=value*1000000
        elif suffix=='K':
            value=value*1000
    except ValueError:
        value=0
    return value

# %%
data['Real value']=data['Value'].apply(val_to_int)
data['Real wage']=data['Wage'].apply(val_to_int)
data.drop(columns=['Value','Wage'],axis=1,inplace=True)
data.head()
# Out:
#                 Name  Age Nationality  Overall  Potential Preferred Foot  \
# 0           L. Messi   31   Argentina       94         94           Left
# 1  Cristiano Ronaldo   33    Portugal       94         94          Right
# 2          Neymar Jr   26      Brazil       92         93          Right
# 3             De Gea   27       Spain       91         93          Right
# 4       K. De Bruyne   27     Belgium       91         92          Right
#
#    International Reputation  Skill Moves       Work Rate   Body Type  ...  \
# 0                       5.0          4.0  Medium/ Medium       Messi  ...
# 1                       5.0          5.0       High/ Low  C. Ronaldo  ...
# 2                       5.0          5.0    High/ Medium      Neymar  ...
# 3                       4.0          1.0  Medium/ Medium        Lean  ...
# 4                       4.0          4.0      High/ High      Normal  ...
#
#   StandingTackle SlidingTackle GKDiving GKHandling GKKicking GKPositioning  \
# ...

# %%
data.groupby(['Nationality'])['Real value'].sum().sort_values(ascending=False).head(5)
# Out:
# Nationality
# Spain        4.706850e+09
# Brazil       3.806375e+09
# France       3.363355e+09
# Germany      3.030110e+09
# Argentina    2.883160e+09
# Name: Real value, dtype: float64

# %%
value = data['Real value']
ax = sns.regplot(x = value / 10000000, y = 'Overall', fit_reg = False, data = data);
ax.set_title(label='Value vs. Overall', fontsize=20);

# %%
print('Maximum Potenial:'+str(data.loc[data['Potential']==max(data['Potential'])]['Name']))
# Out:
# Maximum Potenial:25    K. Mbappé
# Name: Name, dtype: object

# %%
print((data.loc[data['Overall']==max(data['Overall'])]['Name']))
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# Name: Name, dtype: object

# %%
pr_cols=['Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']
i=0
while i<len(pr_cols):
    print('Best {0}:{1}'.format(pr_cols[i],data.loc[data[pr_cols[i]]==max(data[pr_cols[i]])]['Name']))
    i+=1
# Out:
# Best Crossing:4    K. De Bruyne
# Name: Name, dtype: object
# Best Finishing:0    L. Messi
# Name: Name, dtype: object
# Best HeadingAccuracy:102      Naldo
# 204    B. Dost
# Name: Name, dtype: object
# Best ShortPassing:6       L. Modrić
# 13    David Silva
# Name: Name, dtype: object
# Best Volleys:21       E. Cavani
# 28    J. Rodríguez
# 38      G. Higuaín
# 67          Thiago
# 68         M. Reus
# Name: Name, dtype: object
# Best Dribbling:0    L. Messi
# Name: Name, dtype: object
# Best Curve:153    Quaresma
# Name: Name, dtype: object
# Best FKAccuracy:0    L. Messi
# Name: Name, dtype: object
# Best LongPassing:11    T. Kroos
# Name: Name, dtype: object
# Best BallControl:0    L. Messi
# Name: Name, dtype: object
# Best Acceleration:65      Douglas Costa
# 1968            Adama
# Name: Name, dtype: object
# Best SprintSpeed:25      K. Mbappé
# 55        L. Sané
# 1968        Adama
# Name: Name, dtype: object
# Best Agility:2    Neymar Jr
# Name: Name, dtype: object
# ...

# %%
print('Maximum Value:' +str(data.loc[data['Real value']==max(data['Real value'])][['Name']]))
# Out:
# Maximum Value:        Name
# 2  Neymar Jr

# %%
print('Maximum Wage:' +str(data.loc[data['Real wage']==max(data['Real wage'])]['Name']))
# Out:
# Maximum Wage:0    L. Messi
# Name: Name, dtype: object

# %%
sns.jointplot(x=data['Age'],y=data['Potential'],
              joint_kws={'alpha':0.1,'s':5,'color':'red'},
              marginal_kws={'color':'red'})

# %%
sns.lmplot(data = data, x = 'Age', y = 'SprintSpeed',lowess=True,scatter_kws={'alpha':0.01, 's':5,'color':'green'}, 
           line_kws={'color':'red'})
